# %% [markdown]
# # Sequence-to-sequence LSTM

# %%
# Install TensorFlow
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !apt install fluidsynth
# !pip install midi2audio
# !pip install pretty_midi

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, BatchNormalization, Dropout, LSTM, RepeatVector, TimeDistributed, Dense
import numpy as np
import pylab as plt

import sys
sys.path.insert(1, '/content/gdrive/My Drive/Music Gen/import/')
import models
import trainFac
import midiUtils

# %% [markdown]
# ## NN Architecture

# %%
class Model_LSTM_seq2seq(models.Model):

    def __init__(self, input_length, output_length, output_overlap):
        super().__init__(input_length, output_length)
        self.output_overlap = output_overlap
        self.createModel()

    def generateBatches(self, path, batch_size=200, sample_spacing=1):
        generate_songs = self.infiniteSongLoop(path)
        song, idx = None, 0
        x_batch, y_batch = None, None

        i = 0
        while True:
            if x_batch is None:
                x_batch = np.zeros((batch_size, self.input_length, 48), dtype=np.float)
                y_batch = np.zeros((batch_size, self.output_length, 48), dtype=np.float)

            if song is None:
                song = next(generate_songs)
                song_t = np.transpose(song[40:88, ::])
                idx = 0

            if idx + self.input_length + self.output_length - self.output_overlap >= song.shape[1]:
                song = None
                continue         
            
            x_batch[i, ::, ::] = song_t[idx:(idx + self.input_length), ::]
            y_batch[i, ::, ::] = song_t[(idx + self.input_length - self.output_overlap):(idx + self.input_length + self.output_length - self.output_overlap), ::]
            
            idx += sample_spacing
            i += 1
            if i == batch_size:
                yield x_batch, y_batch
                x_batch, y_batch = None, None
                i = 0

    def predict(self, seed, predict_length, threshold=0.5):
        super().predict(seed, predict_length, threshold)
        assert predict_length % (self.output_length - self.output_overlap) == 0, 'Wrong predict length!'

        track = np.transpose(seed)
        result = np.copy(track)
        for _ in range(predict_length // (self.output_length - self.output_overlap)):
            new = self.model.predict(track[np.newaxis, ::, ::])
            new = new[0, -(self.output_length - self.output_overlap):, ::]
            new = (new >= threshold).astype('float')
            result = np.concatenate((result, new), axis=0)
            track = result[-self.input_length:, ::]
        return np.transpose(result)

    def createModel(self):  
        model = Sequential()

        # encoder
        model.add(Input(shape=(self.input_length, 48)))
        model.add(LSTM(256, activation='tanh', return_sequences=True))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
        model.add(LSTM(256, activation='tanh'))

        # decoder
        model.add(RepeatVector(self.output_length))
        num_layers = 2
        for _ in range(num_layers):
            model.add(LSTM(256, activation='tanh', return_sequences=True))
            model.add(BatchNormalization())
            model.add(Dropout(0.3))

        model.add(TimeDistributed(Dense(48, activation="sigmoid")))
        self.model = model
        
modelCompound = Model_LSTM_seq2seq(120, 20, 0)

# modelCompound.model.load_weights('/content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-20-accuracy0.248.hdf5')
modelCompound.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 120, 256)          312320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 120, 256)          1024
# _________________________________________________________________
# dropout (Dropout)            (None, 120, 256)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 20, 256)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20, 256)           525312
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 20, 256)           1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 256)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 20, 256)           525312
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 20, 256)           1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20, 256)           0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 20, 48)            12336
# =================================================================
# Total params: 1,903,664
# Trainable params: 1,902,128
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
paths = trainFac.Paths(
    rootDir = '/content/gdrive/My Drive/Music Gen',
    trainPath = 'train_batches/train_7840_chorus_npz_500',
    testPath  = 'test_batches/test_800_chorus_npz_100',
    testSongPath = 'test_generation/test_songs',
    testGenerateSavePath = 'networks/lstm_seq2seq_256/train1/generate',
    checkpointBasePath = 'networks/lstm_seq2seq_256/train1/checkpoints',
    checkpointName='cnn-{epoch:02d}-accuracy{val_accuracy:.3f}.hdf5')
# create paths if they dont exist
paths.createSavePaths()

trainFacility = trainFac.TrainFacility(modelCompound, paths)
trainFacility.compile()

# %%
history = trainFacility.fit(epochs=20)
# Out:
# Epoch 1/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.1900
# Epoch 00001: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-01-accuracy0.190.hdf5
# create save path
#  -- Generating songs after epoch: 0
#  -- Generating songs finished
# 10000/10000 [==============================] - 617s 62ms/step - loss: 0.1385 - accuracy: 0.1900 - val_loss: 0.1204 - val_accuracy: 0.1895
# Epoch 2/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.2407
# Epoch 00002: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-02-accuracy0.216.hdf5
# 10000/10000 [==============================] - 599s 60ms/step - loss: 0.1105 - accuracy: 0.2407 - val_loss: 0.1208 - val_accuracy: 0.2163
# Epoch 3/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.2753
# Epoch 00003: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-03-accuracy0.257.hdf5
# create save path
#  -- Generating songs after epoch: 2
#  -- Generating songs finished
# 10000/10000 [==============================] - 618s 62ms/step - loss: 0.0963 - accuracy: 0.2753 - val_loss: 0.1207 - val_accuracy: 0.2566
# Epoch 4/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.2859
# Epoch 00004: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-04-accuracy0.232.hdf5
# 10000/10000 [==============================] - 601s 60ms/step - loss: 0.0896 - accuracy: 0.2859 - val_loss: 0.1188 - val_accuracy: 0.2324
# Epoch 5/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.2930
# Epoch 00005: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-05-accuracy0.196.hdf5
# create save path
#  -- Generating songs after epoch: 4
#  -- Generating songs finished
# 10000/10000 [==============================] - 615s 62ms/step - loss: 0.0848 - accuracy: 0.2930 - val_loss: 0.1240 - val_accuracy: 0.1961
# Epoch 6/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.2986
# Epoch 00006: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-06-accuracy0.212.hdf5
# 10000/10000 [==============================] - 601s 60ms/step - loss: 0.0818 - accuracy: 0.2986 - val_loss: 0.1159 - val_accuracy: 0.2117
# Epoch 7/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.3020
# Epoch 00007: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-07-accuracy0.225.hdf5
# create save path
#  -- Generating songs after epoch: 6
#  -- Generating songs finished
# 10000/10000 [==============================] - 612s 61ms/step - loss: 0.0793 - accuracy: 0.3020 - val_loss: 0.1246 - val_accuracy: 0.2246
# Epoch 8/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.3066
# Epoch 00008: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-08-accuracy0.225.hdf5
# 10000/10000 [==============================] - 592s 59ms/step - loss: 0.0772 - accuracy: 0.3066 - val_loss: 0.1230 - val_accuracy: 0.2246
# Epoch 9/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.3107
# Epoch 00009: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-09-accuracy0.213.hdf5
# create save path
#  -- Generating songs after epoch: 8
#  -- Generating songs finished
# 10000/10000 [==============================] - 609s 61ms/step - loss: 0.0753 - accuracy: 0.3107 - val_loss: 0.1165 - val_accuracy: 0.2130
# Epoch 10/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.3142
# Epoch 00010: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-10-accuracy0.208.hdf5
# 10000/10000 [==============================] - 591s 59ms/step - loss: 0.0735 - accuracy: 0.3142 - val_loss: 0.1221 - val_accuracy: 0.2077
# Epoch 11/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.3165
# Epoch 00011: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-11-accuracy0.223.hdf5
# create save path
#  -- Generating songs after epoch: 10
#  -- Generating songs finished
# 10000/10000 [==============================] - 607s 61ms/step - loss: 0.0724 - accuracy: 0.3165 - val_loss: 0.1217 - val_accuracy: 0.2225
# Epoch 12/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.3195
# Epoch 00012: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-12-accuracy0.200.hdf5
# 10000/10000 [==============================] - 593s 59ms/step - loss: 0.0708 - accuracy: 0.3195 - val_loss: 0.1259 - val_accuracy: 0.1996
# Epoch 13/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.3234
# Epoch 00013: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-13-accuracy0.209.hdf5
# create save path
#  -- Generating songs after epoch: 12
#  -- Generating songs finished
# 10000/10000 [==============================] - 607s 61ms/step - loss: 0.0695 - accuracy: 0.3234 - val_loss: 0.1255 - val_accuracy: 0.2090
# Epoch 14/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0684 - accuracy: 0.3252
# Epoch 00014: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-14-accuracy0.218.hdf5
# 10000/10000 [==============================] - 592s 59ms/step - loss: 0.0684 - accuracy: 0.3252 - val_loss: 0.1260 - val_accuracy: 0.2180
# Epoch 15/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.3269
# Epoch 00015: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-15-accuracy0.228.hdf5
# create save path
#  -- Generating songs after epoch: 14
#  -- Generating songs finished
# 10000/10000 [==============================] - 609s 61ms/step - loss: 0.0674 - accuracy: 0.3269 - val_loss: 0.1243 - val_accuracy: 0.2280
# Epoch 16/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.3309
# Epoch 00016: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-16-accuracy0.206.hdf5
# 10000/10000 [==============================] - 593s 59ms/step - loss: 0.0662 - accuracy: 0.3309 - val_loss: 0.1285 - val_accuracy: 0.2062
# Epoch 17/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.3324
# Epoch 00017: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-17-accuracy0.221.hdf5
# create save path
#  -- Generating songs after epoch: 16
#  -- Generating songs finished
# 10000/10000 [==============================] - 606s 61ms/step - loss: 0.0654 - accuracy: 0.3324 - val_loss: 0.1254 - val_accuracy: 0.2206
# Epoch 18/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.3339
# Epoch 00018: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-18-accuracy0.238.hdf5
# 10000/10000 [==============================] - 591s 59ms/step - loss: 0.0647 - accuracy: 0.3339 - val_loss: 0.1241 - val_accuracy: 0.2379
# Epoch 19/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.3373
# Epoch 00019: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-19-accuracy0.214.hdf5
# create save path
#  -- Generating songs after epoch: 18
#  -- Generating songs finished
# 10000/10000 [==============================] - 607s 61ms/step - loss: 0.0634 - accuracy: 0.3373 - val_loss: 0.1311 - val_accuracy: 0.2144
# Epoch 20/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.3385
# Epoch 00020: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/checkpoints/cnn-20-accuracy0.248.hdf5
# 10000/10000 [==============================] - 592s 59ms/step - loss: 0.0629 - accuracy: 0.3385 - val_loss: 0.1253 - val_accuracy: 0.2480

# %%
import json
with open('/content/gdrive/My Drive/Music Gen/networks/lstm_seq2seq_256/train1/history.json', 'w') as fp:
    json.dump(history.history, fp, indent=4)

# %% [markdown]
# ## Experiments

# %%
net_name = 'Seq2seq'
save_path = '/content/gdrive/My Drive/Music Gen/results/seq2seq/'

# %%
song_name = "Can't Stop"
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/cant_stop.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Hells Bells'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/hells_bells.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Layla'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/layla.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Nothing Else Matters'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/nothing_else_matters.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Smells Like Teen Spirit'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/smells_like_teen_spirit.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Under The Bridge'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/under_the_bridge.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Unforgiven 2'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/unforgiven_2.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Unforgiven'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/unforgiven.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Wonderwall'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/wonderwall.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
