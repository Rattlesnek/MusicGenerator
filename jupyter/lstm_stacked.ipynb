# %% [markdown]
# # Stacked LSTM

# %%
# Install TensorFlow
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !apt install fluidsynth
# !pip install midi2audio
# !pip install pretty_midi

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, BatchNormalization, Dropout, LSTM, RepeatVector, TimeDistributed, Dense
import numpy as np
import pylab as plt

import sys
sys.path.insert(1, '/content/gdrive/My Drive/Music Gen/import/')
import models
import trainFac
import midiUtils

# %% [markdown]
# ## NN Architecture

# %%
class Model_LSTM(models.Model):

    def __init__(self, input_length):
        super().__init__(input_length, 1)
        self.createModel()

    def generateBatches(self, path, batch_size=200, sample_spacing=1):
        generate_songs = self.infiniteSongLoop(path)
        song, idx = None, 0
        x_batch, y_batch = None, None

        i = 0
        while True:
            if x_batch is None:
                x_batch = np.zeros((batch_size, self.input_length, 48), dtype=np.float)
                y_batch = np.zeros((batch_size, 48), dtype=np.float)

            if song is None:
                song = next(generate_songs)
                song_t = np.transpose(song[40:88, ::])
                idx = 0

            if idx + self.input_length >= song.shape[1]:
                song = None
                continue         
            
            x_batch[i, ::, ::] = song_t[idx:(idx + self.input_length), ::]
            y_batch[i, ::] = song_t[idx + self.input_length, ::]
            
            idx += sample_spacing
            i += 1
            if i == batch_size:
                yield x_batch, y_batch
                x_batch, y_batch = None, None
                i = 0

    def predict(self, seed, predict_length, threshold=0.5):
        super().predict(seed, predict_length, threshold)
        
        track = np.transpose(seed)
        result = np.copy(track)
        for _ in range(predict_length):
            new = self.model.predict(track[np.newaxis, ::, ::])
            new = (new >= threshold).astype('float')
            result = np.concatenate((result, new), axis=0)
            track = result[-self.input_length:]
        return np.transpose(result)

    def createModel(self):  
        model = Sequential()

        model.add(Input(shape=(self.input_length, 48)))

        num_layers = 2
        for _ in range(num_layers):
            model.add(LSTM(128, activation='tanh', return_sequences=True))
            model.add(BatchNormalization())
            model.add(Dropout(0.3))

        model.add(LSTM(128, activation='tanh'))
        model.add(Dense(48, activation="sigmoid"))
        self.model = model
        
modelCompound = Model_LSTM(120)

# modelCompound.model.load_weights('/content/gdrive/My Drive/Music Gen/networks/lstm_stacked_128/train1/checkpoints/cnn-20-accuracy0.477.hdf5')
modelCompound.model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 120, 128)          90624
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 120, 128)          512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 120, 128)          0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 120, 128)          131584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 120, 128)          512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 120, 128)          0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_2 (Dense)              (None, 48)                6192
# =================================================================
# Total params: 361,008
# Trainable params: 360,496
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
paths = trainFac.Paths(
    rootDir = '/content/gdrive/My Drive/Music Gen',
    trainPath = 'train_batches/train_7840_chorus_npz_500',
    testPath  = 'test_batches/test_800_chorus_npz_100',
    testSongPath = 'test_generation/test_songs',
    testGenerateSavePath = 'networks/lstm_stacked_256/train1/generate',
    checkpointBasePath = 'networks/lstm_stacked_256/train1/checkpoints',
    checkpointName='cnn-{epoch:02d}-accuracy{val_accuracy:.3f}.hdf5')
# create paths if they dont exist
paths.createSavePaths()

trainFacility = trainFac.TrainFacility(modelCompound, paths)
trainFacility.compile()

# %%
history = trainFacility.fit(epochs=20)
# Out:
# Epoch 1/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.4605
# Epoch 00001: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-01-accuracy0.515.hdf5
# create save path
#  -- Generating songs after epoch: 0
#  -- Generating songs finished
# 10000/10000 [==============================] - 866s 87ms/step - loss: 0.0464 - accuracy: 0.4605 - val_loss: 0.0305 - val_accuracy: 0.5150
# Epoch 2/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.4822
# Epoch 00002: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-02-accuracy0.447.hdf5
# 10000/10000 [==============================] - 764s 76ms/step - loss: 0.0331 - accuracy: 0.4822 - val_loss: 0.0293 - val_accuracy: 0.4469
# Epoch 3/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.4902
# Epoch 00003: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-03-accuracy0.490.hdf5
# create save path
#  -- Generating songs after epoch: 2
#  -- Generating songs finished
# 10000/10000 [==============================] - 843s 84ms/step - loss: 0.0298 - accuracy: 0.4902 - val_loss: 0.0283 - val_accuracy: 0.4897
# Epoch 4/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.4921
# Epoch 00004: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-04-accuracy0.480.hdf5
# 10000/10000 [==============================] - 767s 77ms/step - loss: 0.0284 - accuracy: 0.4921 - val_loss: 0.0279 - val_accuracy: 0.4800
# Epoch 5/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.4955
# Epoch 00005: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-05-accuracy0.517.hdf5
# create save path
#  -- Generating songs after epoch: 4
#  -- Generating songs finished
# 10000/10000 [==============================] - 846s 85ms/step - loss: 0.0273 - accuracy: 0.4955 - val_loss: 0.0272 - val_accuracy: 0.5167
# Epoch 6/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.4987
# Epoch 00006: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-06-accuracy0.450.hdf5
# 10000/10000 [==============================] - 767s 77ms/step - loss: 0.0264 - accuracy: 0.4987 - val_loss: 0.0275 - val_accuracy: 0.4503
# Epoch 7/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.4999
# Epoch 00007: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-07-accuracy0.486.hdf5
# create save path
#  -- Generating songs after epoch: 6
#  -- Generating songs finished
# 10000/10000 [==============================] - 844s 84ms/step - loss: 0.0260 - accuracy: 0.4999 - val_loss: 0.0278 - val_accuracy: 0.4857
# Epoch 8/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.5011
# Epoch 00008: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-08-accuracy0.515.hdf5
# 10000/10000 [==============================] - 765s 76ms/step - loss: 0.0255 - accuracy: 0.5011 - val_loss: 0.0274 - val_accuracy: 0.5150
# Epoch 9/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.5043
# Epoch 00009: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-09-accuracy0.515.hdf5
# create save path
#  -- Generating songs after epoch: 8
#  -- Generating songs finished
# 10000/10000 [==============================] - 845s 85ms/step - loss: 0.0251 - accuracy: 0.5043 - val_loss: 0.0276 - val_accuracy: 0.5150
# Epoch 10/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.4994
# Epoch 00010: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-10-accuracy0.508.hdf5
# 10000/10000 [==============================] - 767s 77ms/step - loss: 0.0249 - accuracy: 0.4994 - val_loss: 0.0267 - val_accuracy: 0.5079
# Epoch 11/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.5039
# Epoch 00011: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-11-accuracy0.524.hdf5
# create save path
#  -- Generating songs after epoch: 10
#  -- Generating songs finished
# 10000/10000 [==============================] - 847s 85ms/step - loss: 0.0245 - accuracy: 0.5039 - val_loss: 0.0267 - val_accuracy: 0.5242
# Epoch 12/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.5004
# Epoch 00012: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-12-accuracy0.529.hdf5
# 10000/10000 [==============================] - 765s 77ms/step - loss: 0.0243 - accuracy: 0.5004 - val_loss: 0.0274 - val_accuracy: 0.5286
# Epoch 13/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.5028
# Epoch 00013: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-13-accuracy0.498.hdf5
# create save path
#  -- Generating songs after epoch: 12
#  -- Generating songs finished
# 10000/10000 [==============================] - 845s 85ms/step - loss: 0.0240 - accuracy: 0.5028 - val_loss: 0.0264 - val_accuracy: 0.4978
# Epoch 14/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.5036
# Epoch 00014: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-14-accuracy0.476.hdf5
# 10000/10000 [==============================] - 765s 77ms/step - loss: 0.0238 - accuracy: 0.5036 - val_loss: 0.0264 - val_accuracy: 0.4756
# Epoch 15/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.5039
# Epoch 00015: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-15-accuracy0.490.hdf5
# create save path
#  -- Generating songs after epoch: 14
#  -- Generating songs finished
# 10000/10000 [==============================] - 845s 85ms/step - loss: 0.0237 - accuracy: 0.5039 - val_loss: 0.0266 - val_accuracy: 0.4903
# Epoch 16/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.5036
# Epoch 00016: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-16-accuracy0.509.hdf5
# 10000/10000 [==============================] - 761s 76ms/step - loss: 0.0235 - accuracy: 0.5036 - val_loss: 0.0261 - val_accuracy: 0.5087
# Epoch 17/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.5060
# Epoch 00017: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-17-accuracy0.465.hdf5
# create save path
#  -- Generating songs after epoch: 16
#  -- Generating songs finished
# 10000/10000 [==============================] - 849s 85ms/step - loss: 0.0234 - accuracy: 0.5060 - val_loss: 0.0261 - val_accuracy: 0.4655
# Epoch 18/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.5055
# Epoch 00018: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-18-accuracy0.533.hdf5
# 10000/10000 [==============================] - 767s 77ms/step - loss: 0.0232 - accuracy: 0.5055 - val_loss: 0.0259 - val_accuracy: 0.5328
# Epoch 19/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.5041
# Epoch 00019: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-19-accuracy0.493.hdf5
# create save path
#  -- Generating songs after epoch: 18
#  -- Generating songs finished
# 10000/10000 [==============================] - 847s 85ms/step - loss: 0.0230 - accuracy: 0.5041 - val_loss: 0.0259 - val_accuracy: 0.4925
# Epoch 20/20
# 10000/10000 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.5049
# Epoch 00020: saving model to /content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/checkpoints/cnn-20-accuracy0.483.hdf5
# 10000/10000 [==============================] - 767s 77ms/step - loss: 0.0229 - accuracy: 0.5049 - val_loss: 0.0260 - val_accuracy: 0.4830

# %%
import json
with open('/content/gdrive/My Drive/Music Gen/networks/lstm_stacked_256/train1/history.json', 'w') as fp:
    json.dump(history.history, fp, indent=4)

# %% [markdown]
# ## Experiments

# %%
net_name = 'LSTM Stacked'
save_path = '/content/gdrive/My Drive/Music Gen/results/lstm-stacked/'

# %%
song_name = "Can't Stop"
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/cant_stop.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Hells Bells'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/hells_bells.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Layla'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/layla.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Nothing Else Matters'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/nothing_else_matters.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Smells Like Teen Spirit'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/smells_like_teen_spirit.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Under The Bridge'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/under_the_bridge.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Unforgiven 2'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/unforgiven_2.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Unforgiven'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/unforgiven.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
song_name = 'Wonderwall'
seedPath = '/content/gdrive/My Drive/Music Gen/test_generation/test_songs/wonderwall.npz'

midi = modelCompound.generateMidi(
    seedPath,
    280,
    threshold=0.1)

midiUtils.plotMidi(save_path, net_name, song_name, midi)
midiUtils.playMidi(midi, save_path + midiUtils.joinNames(net_name, song_name))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
